# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/Shareddrives/Ummmies/2022SNUFastMRI/FINAL/Ensemble/final_code_wy
# Out:
# /content/drive/Shareddrives/Ummmies/2022SNUFastMRI/FINAL/Ensemble/final_code_wy

# %%
# SNU fast mri small dataset 압축 해제
import tarfile

train_image = tarfile.open("/content/drive/Shareddrives/Ummmies/dataset/snufastmri_image_small_train.tar.gz")
train_image.extractall("/content")
train_image.close()

train_kspace = tarfile.open("/content/drive/Shareddrives/Ummmies/dataset/snufastmri_kspace_small_train.tar.gz")
train_kspace.extractall("/content")
train_kspace.close()

val_image = tarfile.open("/content/drive/Shareddrives/Ummmies/dataset/snufastmri_image_small_val.tar.gz")
val_image.extractall("/content")
val_image.close()

val_kspace = tarfile.open("/content/drive/Shareddrives/Ummmies/dataset/snufastmri_kspace_small_val.tar.gz")
val_kspace.extractall("/content")
val_kspace.close()

# %%
# SNU fast mri dataset 압축 해제
import tarfile

train_image = tarfile.open("/content/drive/Shareddrives/Ummmies/dataset/snufastmri_image_train.tar.gz")
train_image.extractall("/content")
train_image.close()

train_kspace = tarfile.open("/content/drive/Shareddrives/Ummmies/dataset/snufastmri_kspace_train.tar.gz")
train_kspace.extractall("/content")
train_kspace.close()

val_image = tarfile.open("/content/drive/Shareddrives/Ummmies/dataset/snufastmri_image_val.tar.gz")
val_image.extractall("/content")
val_image.close()

val_kspace = tarfile.open("/content/drive/Shareddrives/Ummmies/dataset/snufastmri_kspace_val.tar.gz")
val_kspace.extractall("/content")
val_kspace.close()

# %%
# SNU fast mri leadertboard dataset 압축 해제
import tarfile

train_image = tarfile.open("/content/drive/Shareddrives/Ummmies/dataset/snufastmri_image_leaderboard.tar.gz")
train_image.extractall("/content/leaderboard/image")
train_image.close()

train_kspace = tarfile.open("/content/drive/Shareddrives/Ummmies/dataset/snufastmri_kspace_leaderboard.tar.gz")
train_kspace.extractall("/content/leaderboard/kspace")
train_kspace.close()

# %%
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for gputil: filename=GPUtil-1.4.0-py3-none-any.whl size=7411 sha256=8c6338a252caa6e51f4fa8cbf812bf8c6bfa9176e718d435968b627b833dcd22
#   Stored in directory: /root/.cache/pip/wheels/6e/f8/83/534c52482d6da64622ddbf72cd93c35d2ef2881b78fd08ff0c
# Successfully built gputil
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python3 train.py
# Out:
# Current cuda device:  0
# VarNet Best Model: Epoch = 1 , ValLoss = 0.01949
# MultiDomainNet Best Model: Epoch = 1 , ValLoss = 0.01999
# CrossDomainNet7 Best Model: Epoch = 14 , ValLoss = 0.02
# CrossDomainNet8 Best Model: Epoch = 29 , ValLoss = 0.01954
# Traceback (most recent call last):
#   File "train.py", line 53, in <module>
#     train_all(args)
#   File "/content/drive/Shareddrives/Ummmies/2022SNUFastMRI/FINAL/Ensemble/final_code_wy/utils/learning/train_part.py", line 486, in train_all
#     ensemble_train(args)
#   File "/content/drive/Shareddrives/Ummmies/2022SNUFastMRI/FINAL/Ensemble/final_code_wy/utils/learning/train_part.py", line 445, in ensemble_train
#     train_loader = create_data_loaders(data_path = args.data_path_train, args = args)
#   File "/content/drive/Shareddrives/Ummmies/2022SNUFastMRI/FINAL/Ensemble/final_code_wy/utils/data/load_data.py", line 83, in create_data_loaders
#     isval = isval
# ...

# %%
# !python3 test.py
# !python3 leaderboard_eval.py
# Out:
# Current cuda device  0
# VarNet Best Model: Epoch = 1 , ValLoss = 0.01949
# MultiDomainNet Best Model: Epoch = 1 , ValLoss = 0.01999
# CrossDomainNet7 Best Model: Epoch = 14 , ValLoss = 0.02
# CrossDomainNet8 Best Model: Epoch = 29 , ValLoss = 0.01954
# ensemblenet Best Model: Epoch = 8 , ValLoss = 0.02761
# Leaderboard Dataset SSIM : 0.9850
